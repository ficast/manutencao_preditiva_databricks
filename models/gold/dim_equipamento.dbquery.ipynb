# %% [markdown]
# # Dimensão Equipamento (Snapshot Atual)
#
# Visão SCD Type 1 (Current Snapshot) baseada na Silver.

# %%
spark.sql(f"""
CREATE OR REPLACE TABLE {fqtn(SCHEMA_GOLD, 'dim_equipamento')} AS
SELECT 
    equipment_id,
    equipment_name,
    equipment_type,
    location,
    manufacturer,
    model,
    status as current_status,
    installation_date
FROM {fqtn(SCHEMA_SILVER, 'equipment_clean')}
""")
